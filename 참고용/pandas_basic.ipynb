# %% [markdown]
# # CRUD
#
# ### Create(생성), Read(읽기), Update(갱신), Delete(삭제)
#
# ### https://wikidocs.net/153209

# %% [markdown]
# ## 1. Create

# %%
import pandas as pd
obj = pd.Series([4, 7, -5, 3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj2 = pd.Series([4, 7, -5, 3], index=['dd', 'bf', 'as', 'c'])
obj2
# Out:
# dd    4
# bf    7
# as   -5
# c     3
# dtype: int64

# %%
sdata = {'Kim': 35000, 'Beomwoo': 67000, 'Joan': 12000, 'Choi': 4000}
obj3 = pd.Series(sdata)
obj3
# Out:
# Kim        35000
# Beomwoo    67000
# Joan       12000
# Choi        4000
# dtype: int64

# %%
obj3.name = 'Salary'
obj3.index.name = "Names"
obj3
# Out:
# Names
# Kim        35000
# Beomwoo    67000
# Joan       12000
# Choi        4000
# Name: Salary, dtype: int64

# %%
na = None
col  = ['col1','col2','col3','col4','col5']
row  = [1,2,3,4,5,6,7]
data = [[na, 2,na, 4,na],
        [ 6, 7,na, 9,na],
        [11,na,na,14,15],
        [na,17,1,na,20],
        [na,3,na,na,25],
        [22,na,na,4,3],
        [na,22,na,na,na]
        ]
df = pd.DataFrame(data,row,col)
df
# Out:
#    col1  col2  col3  col4  col5
# 1   NaN   2.0   NaN   4.0   NaN
# 2   6.0   7.0   NaN   9.0   NaN
# 3  11.0   NaN   NaN  14.0  15.0
# 4   NaN  17.0   1.0   NaN  20.0
# 5   NaN   3.0   NaN   NaN  25.0
# 6  22.0   NaN   NaN   4.0   3.0
# 7   NaN  22.0   NaN   NaN   NaN

# %%
# Data Frame 정의하기
# 이전에 DataFrame에 들어갈 데이터를 정의해주어야 하는데,
# 이는 python의 dictionary 또는 numpy의 array로 정의할 수 있다.
data = {'name': ['Beomwoo', 'Beomwoo', 'Beomwoo', 'Kim', 'Park'],
        'year': [2013, 2014, 2015, 2016, 2015],
        'points': [1.5, 1.7, 3.6, 2.4, 2.9]}
df2 = pd.DataFrame(data)
df2
# Out:
#       name  year  points
# 0  Beomwoo  2013     1.5
# 1  Beomwoo  2014     1.7
# 2  Beomwoo  2015     3.6
# 3      Kim  2016     2.4
# 4     Park  2015     2.9

# %%
na = None
list2 = [1,2,3,4,5]
col = {'a':[na,3, 4, 5, 6], 'b':[1,2,3,4,5], 'c':list2}     # list에 read_csv도 가능=> 바로 데이터프레임에 삽입 가능
df3 = pd.DataFrame(col)
df3['d'] = 2,3,4,5,6
df3

## read_csv는 , 형태인 파일을 가지고 온것임
# Out:
#      a  b  c  d
# 0  NaN  1  1  2
# 1  3.0  2  2  3
# 2  4.0  3  3  4
# 3  5.0  4  4  5
# 4  6.0  5  5  6

# %% [markdown]
# ## 2. Read

# %%
df.info()
df.describe()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 1 to 7
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    3 non-null      float64
#  1   col2    5 non-null      float64
#  2   col3    1 non-null      float64
#  3   col4    4 non-null      float64
#  4   col5    4 non-null      float64
# dtypes: float64(5)
# memory usage: 336.0 bytes
#    col1  col2  col3  col4  col5
# 1   NaN   2.0   NaN   4.0   NaN
# 2   6.0   7.0   NaN   9.0   NaN
# 3  11.0   NaN   NaN  14.0  15.0
# 4   NaN  17.0   1.0   NaN  20.0
# 5   NaN   3.0   NaN   NaN  25.0

# %%
#칼럼확인, dtype 잘 보기
df.columns
# Out:
# Index(['col1', 'col2', 'col3', 'col4', 'col5'], dtype='object')

# %%
#각행확인
df.values
# Out:
# array([[nan,  2., nan,  4., nan],
#        [ 6.,  7., nan,  9., nan],
#        [11., nan, nan, 14., 15.],
#        [nan, 17.,  1., nan, 20.],
#        [nan,  3., nan, nan, 25.],
#        [22., nan, nan,  4.,  3.],
#        [nan, 22., nan, nan, nan]])

# %%
# df['col1'] #열하나만 추출
# df[['col1', 'col2']] #리스트로 넣어서 여러열 추출
df.loc[0:4, ['col1', 'col2']] #지정행만 추출 복수일경우 리스트
# # 위치 : df.loc[행:열]     # 데이터의 구체적인 이름은 아는데 열위치 모를 때 사용
# df.iloc[0:4, 0:2]         # 열의 구체적 위치 알 때 사용
# df.index
# Out:
#    col1  col2
# 1   NaN   2.0
# 2   6.0   7.0
# 3  11.0   NaN
# 4   NaN  17.0

# %%
df
# Out:
#    col1  col2  col3  col4  col5
# 1   NaN   2.0   NaN   4.0   NaN
# 2   6.0   7.0   NaN   9.0   NaN
# 3  11.0   NaN   NaN  14.0  15.0
# 4   NaN  17.0   1.0   NaN  20.0
# 5   NaN   3.0   NaN   NaN  25.0
# 6  22.0   NaN   NaN   4.0   3.0
# 7   NaN  22.0   NaN   NaN   NaN

# %%
df.loc[0:, ['col1', 'col2']]
# df
# Out:
#    col1  col2
# 1   NaN   2.0
# 2   6.0   7.0
# 3  11.0   NaN
# 4   NaN  17.0
# 5   NaN   3.0
# 6  22.0   NaN
# 7   NaN  22.0

# %%
#loc, iloc의 차이는 loc은 열의 구체적 이름, iloc은 열인덱스로 활용
df.iloc[3] # 3번째 행을 가져온다.
# df.iloc[3:5, 0:2] #행 렬
# Out:
# col1     NaN
# col2    17.0
# col3     1.0
# col4     NaN
# col5    20.0
# Name: 4, dtype: float64

# %% [markdown]
# ## 3. Update

# %%
# 각 인덱스에 대한 이름 설정하기
df.index.name = '#'

#칼럼에 대한 인덱스 네임
df.columns.name = 'name'
df
# Out:
# name  col1  col2  col3  col4  col5
# #
# 1      NaN   2.0   NaN   4.0   NaN
# 2      6.0   7.0   NaN   9.0   NaN
# 3     11.0   NaN   NaN  14.0  15.0
# 4      NaN  17.0   1.0   NaN  20.0
# 5      NaN   3.0   NaN   NaN  25.0
# 6     22.0   NaN   NaN   4.0   3.0
# 7      NaN  22.0   NaN   NaN   NaN

# %%
# index 변경
df.index = ['A', 'B', 'C', 'D', 'E', 'F', 'G']
df
# Out:
# name  col1  col2  col3  col4  col5
# A      NaN   2.0   NaN   4.0   NaN
# B      6.0   7.0   NaN   9.0   NaN
# C     11.0   NaN   NaN  14.0  15.0
# D      NaN  17.0   1.0   NaN  20.0
# E      NaN   3.0   NaN   NaN  25.0
# F     22.0   NaN   NaN   4.0   3.0
# G      NaN  22.0   NaN   NaN   NaN

# %%
# #인덱스 재지정의 경우 항상 새로 df를 만들어서 실수를 배제할것

# df.reset_index(inplace=True, drop=True) #바꾸냐 안바꾸냐/지우냐안지우냐
# # df.drop(columns='index',inplace=True)
# df22 = df.set_index('col2', inplace=True) #기존행을 인덱스로 지정하냐안하냐, 새로운 df필요
# df22.reset_index(inplace=True) #이럴경우 
# df22

# %%
#열추가
df['col6']=df.index
df['col7'] = df['col2'] - df['col4']
df
# Out:
# name  col1  col2  col3  col4  col5 col6  col7
# A      NaN   2.0   NaN   4.0   NaN    A  -2.0
# B      6.0   7.0   NaN   9.0   NaN    B  -2.0
# C     11.0   NaN   NaN  14.0  15.0    C   NaN
# D      NaN  17.0   1.0   NaN  20.0    D   NaN
# E      NaN   3.0   NaN   NaN  25.0    E   NaN
# F     22.0   NaN   NaN   4.0   3.0    F   NaN
# G      NaN  22.0   NaN   NaN   NaN    G   NaN

# %%
# 새로 만들어서 
df['col4>1'] = df['col4'] > 1.0
df
# Out:
# name  col1  col2  col3  col4  col5 col6  col7  col4>1
# A      NaN   2.0   NaN   4.0   NaN    A  -2.0    True
# B      6.0   7.0   NaN   9.0   NaN    B  -2.0    True
# C     11.0   NaN   NaN  14.0  15.0    C   NaN    True
# D      NaN  17.0   1.0   NaN  20.0    D   NaN   False
# E      NaN   3.0   NaN   NaN  25.0    E   NaN   False
# F     22.0   NaN   NaN   4.0   3.0    F   NaN    True
# G      NaN  22.0   NaN   NaN   NaN    G   NaN   False

# %%
df_200 = df.loc[df['연도']== 200]
df_2018 = df_200.loc[df['클러스터']== 2018]


for i in range(11,22):
    globals()[f'magic{i}'] = magic(ga, ne_Df, f'20{i}')

# %%
# 조건에 따라 값 대체
df.loc[df['col2'] > 3, 'col2'] = "yes"
df

## 컬럼6이 >
# Out:
# name  col1 col2  col3  col4  col5 col6  col7  col4>1
# A      NaN  2.0   NaN   4.0   NaN    A  -2.0    True
# B      6.0  yes   NaN   9.0   NaN    B  -2.0    True
# C     11.0  NaN   NaN  14.0  15.0    C   NaN    True
# D      NaN  yes   1.0   NaN  20.0    D   NaN   False
# E      NaN  3.0   NaN   NaN  25.0    E   NaN   False
# F     22.0  NaN   NaN   4.0   3.0    F   NaN    True
# G      NaN  yes   NaN   NaN   NaN    G   NaN   False

# %%
df.loc[df['col4>1'] == 1, 'col4>1'] = True
df.loc[df['col4>1'] == 0, 'col4>1'] = False
df
# Out:
# name  col1 col2  col3  col4  col5 col6  col7  col4>1
# A      NaN  2.0   NaN   4.0   NaN    A  -2.0    True
# B      6.0  yes   NaN   9.0   NaN    B  -2.0    True
# C     11.0  NaN   NaN  14.0  15.0    C   NaN    True
# D      NaN  yes   1.0   NaN  20.0    D   NaN   False
# E      NaN  3.0   NaN   NaN  25.0    E   NaN   False
# F     22.0  NaN   NaN   4.0   3.0    F   NaN    True
# G      NaN  yes   NaN   NaN   NaN    G   NaN   False

# %%
# na = None
list2 = [1,2,3,4,5]
col = {'a':[2,3, 4, 5, 6], 'b':[1,2,3,4,5], 'c':list2}     # list에 read_csv도 가능=> 바로 데이터프레임에 삽입 가능
d3 = pd.DataFrame(col)
d3['d'] = 2,3,4,5,6
d3

## read_csv는 , 형태인 파일을 가지고 온것임
# Out:
#    a  b  c  d
# 0  2  1  1  2
# 1  3  2  2  3
# 2  4  3  3  4
# 3  5  4  4  5
# 4  6  5  5  6

# %%
d3.loc[d3['c'] < d3['d'], 'b>d'] = 1
d3
# Out:
#    a  b  c  d  b>d
# 0  2  1  1  2  1.0
# 1  3  2  2  3  1.0
# 2  4  3  3  4  1.0
# 3  5  4  4  5  1.0
# 4  6  5  5  6  1.0

# %%
df.loc['8',:] = [22,None,None,4,4,1,-2.0] #행추가
df
# Out:
#      col1  col2  col3  col4  col5  col6 col7
# 1     NaN   2.0   NaN   4.0   NaN   1.0 -2.0
# 2     6.0   7.0   NaN   9.0   NaN   2.0 -2.0
# 3    11.0   NaN   NaN  14.0  15.0   3.0  NaN
# 4     NaN  17.0   1.0   NaN  20.0   4.0  yes
# 5     NaN   3.0   NaN   NaN  25.0   5.0  yes
# 6    22.0   NaN   NaN   4.0   3.0   6.0  yes
# 7     NaN  22.0   NaN   NaN   NaN   7.0  yes
# 8    22.0   NaN   NaN   4.0   4.0   8.0 -2.0
# 2.5  22.0   NaN   NaN   4.0   4.0   1.0 -2.0

# %% [markdown]
# ## 4. Delete

# %%
#행삭제 = 인덱스로 지정
df.drop(index='2.5',inplace=True)
df
# Out:
#    col1  col2  col3  col4  col5  col6 col7
# 1   NaN   2.0   NaN   4.0   NaN   1.0 -2.0
# 2   6.0   7.0   NaN   9.0   NaN   2.0 -2.0
# 3  11.0   NaN   NaN  14.0  15.0   3.0  NaN
# 4   NaN  17.0   1.0   NaN  20.0   4.0  yes
# 5   NaN   3.0   NaN   NaN  25.0   5.0  yes
# 6  22.0   NaN   NaN   4.0   3.0   6.0  yes
# 7   NaN  22.0   NaN   NaN   NaN   7.0  yes
# 8  22.0   NaN   NaN   4.0   4.0   8.0 -2.0

# %%
df.drop(columns=['col6', 'col7'], inplace=True) 
df
# Out:
#    col1  col2  col3  col4  col5  col6
# 1   NaN   2.0   NaN   4.0   NaN   1.0
# 2   6.0   7.0   NaN   9.0   NaN   2.0
# 3  11.0   NaN   NaN  14.0  15.0   3.0
# 4   NaN  17.0   1.0   NaN  20.0   4.0
# 5   NaN   3.0   NaN   NaN  25.0   5.0
# 6  22.0   NaN   NaN   4.0   3.0   6.0
# 7   NaN  22.0   NaN   NaN   NaN   7.0
# 8  22.0   NaN   NaN   4.0   4.0   8.0

# %%
# (추천)살릴경우 데이터프레임 새로 만들어줘야함
df2 = df.drop(index=[1,2,3]) #인덱스 1,2,3번째 지우고 df2로 새로만듬
df2
# Out:
#    col1  col2  col3  col4  col5  col6
# 4   NaN  17.0   1.0   NaN  20.0   4.0
# 5   NaN   3.0   NaN   NaN  25.0   5.0
# 6  22.0   NaN   NaN   4.0   3.0   6.0
# 7   NaN  22.0   NaN   NaN   NaN   7.0
# 8  22.0   NaN   NaN   4.0   4.0   8.0

# %% [markdown]
# # 결측치
#
# ### 확인
# ### 삭제
# ### 채우기(전값, 후값, 평균값 등)

# %%
df
# Out:
#    col1  col2  col3  col4  col5  col6
# 0   NaN   2.0   NaN   4.0   NaN   1.0
# 1   6.0   7.0   NaN   9.0   NaN   2.0
# 2  11.0   NaN   NaN  14.0  15.0   3.0
# 3   NaN  17.0   1.0   NaN  20.0   4.0
# 4   NaN   3.0   NaN   NaN  25.0   5.0
# 5  22.0   NaN   NaN   4.0   3.0   6.0
# 6   NaN  22.0   NaN   NaN   NaN   7.0
# 7  22.0   NaN   NaN   4.0   4.0   8.0

# %%
#확인
df.isnull().sum() #isnull()의 True(결측값)을 더한것
df.notnull().sum() #결측이 아닌 데이터의 개수를 더한것
df.loc[df.isnull()['특정행'],:] # F열에서 nan값을 포함하는 행만 추출하기        ## 결측치가 있는 행의 위치를 뽑아줌 #중요

#삭제
df.dropna(how='any') #행중 값이 하나라도 없으면 다삭제
df.dropna(how='all') #행의 모든값이 없으면 그 행을 삭제
df.dropna(subset=['특정열']) #특정열에거 결측치가 있을경우 그 행을 다삭제

#수정
#DataFrame.fillna(value=None, method=None, axis=None, inplace=False, limit=None, downcast=None)
df.fillna(0) #0으로 다채우기
df.fillna({'특정행':df['특정행'].mean()}) #특정행의 결측값을 특정행의 평균값으로 채움, max(), min()등 가능      #중요
df.fillna({'특정행1':'특정값','특정행2':'특정값'}) #다중행도 처리가능함
df.fillna(method='ffill') #앞의값(윗행)으로채우기
df.fillna(method='bfill') #뒤의값(아래행)으로채우기
