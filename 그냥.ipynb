# %%
import pandas as pd

# %%
df = pd.read_csv('데이터/data/부실기업지정.csv', encoding='CP949')
df
# Out:
#        Unnamed: 0       회사명     회계년도      상장일 상장폐지일  이자보상배율  매출액증가율  부실기업1  \
# 0               0  (주)CMG제약  2011/12  2001/08   NaN    3.53   56.40    0.0
# 1               1  (주)CMG제약  2012/12  2001/08   NaN   -7.75   -8.43    0.0
# 2               2  (주)CMG제약  2013/12  2001/08   NaN    0.70   25.51    0.0
# 3               3  (주)CMG제약  2014/12  2001/08   NaN    3.60   11.52    0.0
# 4               4  (주)CMG제약  2015/12  2001/08   NaN  -32.22   18.85    0.0
# ...           ...       ...      ...      ...   ...     ...     ...    ...
# 17622       17622   흥아해운(주)  2016/12  1976/06   NaN    0.21   -1.58    0.0
# 17623       17623   흥아해운(주)  2017/12  1976/06   NaN   -0.42    0.56    0.0
# 17624       17624   흥아해운(주)  2018/12  1976/06   NaN   -1.16   -9.87    1.0
# 17625       17625   흥아해운(주)  2019/12  1976/06   NaN   -0.55  -86.45    1.0
# 17626       17626   흥아해운(주)  2020/12  1976/06   NaN   -0.38  -12.95    1.0
#
# ...

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df["이자보상배율"] == 999999999
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17622    False
# 17623    False
# 17624    False
# 17625    False
# 17626    False
# Name: 이자보상배율, Length: 17627, dtype: bool

# %%
df.head(10)
# Out:
#         회사명     회계년도      상장일 상장폐지일        이자보상배율  매출액증가율  부실기업1  부실기업2  부실기업  \
# 0  (주)CMG제약  2011/12  2001/08   NaN  3.530000e+00   56.40    0.0    0.0     0
# 1  (주)CMG제약  2012/12  2001/08   NaN -7.750000e+00   -8.43    0.0    0.0     0
# 2  (주)CMG제약  2013/12  2001/08   NaN  7.000000e-01   25.51    0.0    0.0     0
# 3  (주)CMG제약  2014/12  2001/08   NaN  3.600000e+00   11.52    0.0    0.0     0
# 4  (주)CMG제약  2015/12  2001/08   NaN -3.222000e+01   18.85    0.0    0.0     0
# 5  (주)CMG제약  2016/12  2001/08   NaN  1.000000e+09   21.92    0.0    0.0     0
# 6  (주)CMG제약  2017/12  2001/08   NaN  1.000000e+09   25.98    0.0    0.0     0
# 7  (주)CMG제약  2018/12  2001/08   NaN  1.000000e+09   20.05    0.0    0.0     0
# 8  (주)CMG제약  2019/12  2001/08   NaN  3.030000e+02   17.56    0.0    0.0     0
# 9  (주)CMG제약  2020/12  2001/08   NaN  7.974000e+01    9.96    0.0    0.0     0
#
#     업종  ...   자본집약도  총자본투자효율  설비투자효율  기계투자효율  부가가치율  노동소득분배율  \
# ...

# %%
df.loc[df['이자보상배율'] == 999999999, '이자보상배율'] = 1
df.head(10)
# 1-> 그 기업에 99값 뺀 평균으로
# Out:
#         회사명     회계년도      상장일 상장폐지일  이자보상배율  매출액증가율  부실기업1  부실기업2  부실기업   업종  \
# 0  (주)CMG제약  2011/12  2001/08   NaN    3.53   56.40    0.0    0.0     0  제조업
# 1  (주)CMG제약  2012/12  2001/08   NaN   -7.75   -8.43    0.0    0.0     0  제조업
# 2  (주)CMG제약  2013/12  2001/08   NaN    0.70   25.51    0.0    0.0     0  제조업
# 3  (주)CMG제약  2014/12  2001/08   NaN    3.60   11.52    0.0    0.0     0  제조업
# 4  (주)CMG제약  2015/12  2001/08   NaN  -32.22   18.85    0.0    0.0     0  제조업
# 5  (주)CMG제약  2016/12  2001/08   NaN    1.00   21.92    0.0    0.0     0  제조업
# 6  (주)CMG제약  2017/12  2001/08   NaN    1.00   25.98    0.0    0.0     0  제조업
# 7  (주)CMG제약  2018/12  2001/08   NaN    1.00   20.05    0.0    0.0     0  제조업
# 8  (주)CMG제약  2019/12  2001/08   NaN  303.00   17.56    0.0    0.0     0  제조업
# 9  (주)CMG제약  2020/12  2001/08   NaN   79.74    9.96    0.0    0.0     0  제조업
#
#    ...   자본집약도  총자본투자효율  설비투자효율  기계투자효율  부가가치율  노동소득분배율  CASH FLOW 대 매출액비율  \
# ...

# %%
df = pd.read_csv('데이터/1차 전처리/연결별도병합.csv', encoding='CP949')
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df
# Out:
#             회사명  거래소코드     회계년도 통계청 한국표준산업분류 10차  총자본증가율  정상영업이익증가율  순이익증가율  \
# 0      (주)CMG제약  58820  2011/12              제조업    1.98       0.00    0.00
# 1      (주)CMG제약  58820  2012/12              제조업  109.15       0.00    0.00
# 2      (주)CMG제약  58820  2013/12              제조업   -2.09       0.00    0.00
# 3      (주)CMG제약  58820  2014/12              제조업    3.86     -44.10  -46.64
# 4      (주)CMG제약  58820  2015/12              제조업   -2.64       0.00    0.00
# ...         ...    ...      ...              ...     ...        ...     ...
# 18016   흥아해운(주)   3280  2016/12         운수 및 창고업   21.08     -72.25 -263.29
# 18017   흥아해운(주)   3280  2017/12         운수 및 창고업  -11.43    -322.17    0.00
# 18018   흥아해운(주)   3280  2018/12         운수 및 창고업   -5.33       0.00    0.00
# 18019   흥아해운(주)   3280  2019/12         운수 및 창고업  -46.38       0.00    0.00
# 18020   흥아해운(주)   3280  2020/12         운수 및 창고업  -33.46       0.00    0.00
#
# ...
